# %%
! ./installation.sh

# %%
import prepare_data
url2record, groups, url2group, markups = prepare_data.prepare_data(train=True)

# %% [markdown]
# # ROUGE

# %%
import rouge
print(rouge.evaluate_rouge(groups, markups, url2record, rouge_type='rouge1', threshold=0.01))
# Out:
# ...
# 100%|██████████| 945/945 [00:34<00:00, 27.54it/s]
# 0.5190905190905191

# %%
print(rouge.evaluate_rouge(groups, markups, url2record, rouge_type='rouge2', threshold=0.01))
# Out:
# 100%|██████████| 945/945 [00:35<00:00, 26.28it/s]
# 0.49842699842699845

# %%
print(rouge.evaluate_rouge(groups, markups, url2record, rouge_type='rougeL', threshold=0.01))
# Out:
# 100%|██████████| 945/945 [00:59<00:00, 15.90it/s]
# 0.5212355212355212

# %% [markdown]
# # BERTScore

# %%
import bertscore 
print(bertscore.evaluate_bertscore(groups, markups, url2record, model_type="bert-base-multilingual-cased", threshold=0.01))
# Out:
# ...
# 100%|██████████| 945/945 [15:24<00:00,  1.02it/s]
# 0.5334620334620335

# %%
print(bertscore.evaluate_bertscore(groups, markups, url2record, model_type="distilbert-base-multilingual-cased", threshold=0.01))
# Out:
# ...
# 100%|██████████| 945/945 [10:59<00:00,  1.43it/s]
# 0.5413270413270413

# %%
print(bertscore.evaluate_bertscore(groups, markups, url2record, model_type="distilbert-base-uncased", threshold=0.01))
# Out:
# 100%|██████████| 945/945 [14:15<00:00,  1.10it/s]
# 0.5391820391820392

# %%
print(bertscore.evaluate_bertscore(groups, markups, url2record, model_type="xlm-roberta-large", threshold=0.01))
# Out:
# 100%|██████████| 945/945 [30:34<00:00,  1.94s/it]
# 0.5345345345345346

# %%
import torch
torch.cuda.empty_cache()

# %%
print(bertscore.evaluate_bertscore(groups, markups, url2record, model_type="bert-base-uncased", threshold=0.01))
# Out:
# ...
# 100%|██████████| 945/945 [18:41<00:00,  1.19s/it]
# 0.5481910481910481

# %%
print(bertscore.evaluate_bertscore(groups, markups, url2record, model_type="microsoft/deberta-large-mnli", threshold=0.01))
# Out:
# ...
# 100%|██████████| 945/945 [53:58<00:00,  3.43s/it]
# 0.5408980408980409

# %%
import torch
torch.cuda.empty_cache()

# %%
print(bertscore.evaluate_bertscore(groups, markups, url2record, model_type="facebook/bart-large-mnli", threshold=0.01))
# Out:
# ...
# 100%|██████████| 945/945 [48:13<00:00,  3.06s/it]
# 0.5220935220935221
